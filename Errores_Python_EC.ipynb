# %% [markdown]
# # Errores

# %% [markdown]
# 1. AssertionError: En este caso nos indica que algo "imposible" ha sucedido.

# %%
##Ejemplo con uso de assert
price=20
discount= 60 #Descuento del 45%
def calculate_discount(price, discount):
    discounted_price = price - (discount*price)
    assert 0 <= discounted_price <= price
    print(discounted_price)
    return;

calculate_discount(price, discount)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-1-27d8bbd37a88> in <module>
#       8     return;
#       9
# ---> 10 calculate_discount(price, discount)
#
# <ipython-input-1-27d8bbd37a88> in calculate_discount(price, discount)
#       4 def calculate_discount(price, discount):
#       5     discounted_price = price - (discount*price)
# ----> 6     assert 0 <= discounted_price <= price
#       7     print(discounted_price)
#       8     return;
#
# AssertionError:

# %% [markdown]
# 2. ZeroDivisionError: Aparece cuando se intenta dividir por 0.

# %%
try:
    dividendo = int(input('Introduce el dividendo: '))
    divisor = int(input('Introduce el divisor: '))
    print('El cociente de la división de ambos números es', dividendo//divisor)
finally:
    print("Finalizado")
# Out:
# Introduce el dividendo: 12
# Introduce el divisor: 0
# Finalizado
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-b2918d1bcbbf> in <module>
#       2     dividendo = int(input('Introduce el dividendo: '))
#       3     divisor = int(input('Introduce el divisor: '))
# ----> 4     print('El cociente de la división de ambos números es', dividendo//divisor)
#       5 finally:
#       6     print("Finalizado")
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# 3. Exception: Exception se usa para controlar cualquier error que ocurra durante la ejecución del programa y ya que en este caso se ingresa un valor que no va de acuerdo a la condición aparece Exception pero como error.

# %%
num = int(input("Ingrese un número positivo: "))

if num<0:
    raise Exception("Por favor sólo ingrese números positivos (mayores a 0) ")

print("num = ", num)
# Out:
# Ingrese un número positivo: -8
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-ed5b52dfda7b> in <module>
#       2
#       3 if num<0:
# ----> 4     raise Exception("Por favor sólo ingrese números positivos (mayores a 0) ")
#       5
#       6 print("num = ", num)
#
# Exception: Por favor sólo ingrese números positivos (mayores a 0)

# %% [markdown]
# 4. NameError: En este caso aparece NameError porque no se escribió correctamente print.

# %%
##Calcular la suma de los números usando while
print("Se va a calcular la suma de los números de 0 a 100 tomando intervalos de 10 unidades")
suma=0
ite=0
while ite!=110:
    suma=suma+ite
    ite+=10
pint(suma)
# Out:
# Se va a calcular la suma de los números de 0 a 100 tomando intervalos de 10 unidades
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\jaimc\Desktop\Errores Python.ipynb Celda 9 in <cell line: 8>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jaimc/Desktop/Errores%20Python.ipynb#X33sZmlsZQ%3D%3D?line=5'>6</a>     suma=suma+ite
#       <a href='vscode-notebook-cell:/c%3A/Users/jaimc/Desktop/Errores%20Python.ipynb#X33sZmlsZQ%3D%3D?line=6'>7</a>     ite+=10
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jaimc/Desktop/Errores%20Python.ipynb#X33sZmlsZQ%3D%3D?line=7'>8</a> pint(suma)
#
# NameError: name 'pint' is not defined

# %% [markdown]
# 5. SyntaxError: Aparece porque no tiene coma en la línea 25 entre el primer texto y la variable num.

# %%
##Definir si un número es primo usando for
class Counter:
    contador=0
print("Se definirá si un número es primo usando ciclo for")
num=int(input("Ingrese un número entero: "))
if num==0:
    print("El número es cero")
elif num==1:
    print("El número 1 es primo")
elif num==2:
    print("El número 2 es primo")
elif num==3:
    print("El número 3 es primo")
elif num==5:
    print("El número 5 es primo")
elif num==7:
    print("El número 7 es primo")
elif num<0:
    print("No se aceptan números negativos")
else:
    for n in range(2,8):
        if (num%n)==0:
            Counter.contador+=1
    if Counter.contador>=1:
        print("El número"num,"no es primo")
    else:
        print("El número",num,"es primo")
# Out:
#   File "<ipython-input-6-842654513db6>", line 25
#     print("El número"num,"no es primo")
#                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 6. IndexError: Ocurre cuando se intenta acceder a una secuencia con un índice que no existe.

# %%
l = []
l.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-3290a6f44f1f> in <module>
#       1 l = []
# ----> 2 l.pop()
#
# IndexError: pop from empty list

# %% [markdown]
# 7. TypeError: Ocurre cuando se realiza una operación a datos de distintos tipos.

# %%
'2' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d2b23a1db757> in <module>
# ----> 1 '2' + 2
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# 8. ValueError: La función recibe un argumento de un tipo inapropiado.

# %%
n = float(input("Introduce un número: "))
m = 4
print("{}/{} = {}".format(n,m,n/m))
# Out:
# Introduce un número: aaa
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-bcb340f22532> in <module>
# ----> 1 n = float(input("Introduce un número: "))
#       2 m = 4
#       3 print("{}/{} = {}".format(n,m,n/m))
#
# ValueError: could not convert string to float: 'aaa'

# %% [markdown]
# 9. OverflowError: La operación almacena un valor por encima de su límite por lo que aparece un error de memoria ya que este se desborda por encima del límite ya definido.

# %%
j = 5.0

for i in range(1, 1000):
    j = j**i
    print(j)
# Out:
# 5.0
# 25.0
# 15625.0
# 5.960464477539062e+16
# 7.52316384526264e+83
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-11-4bd894603183> in <module>
#       2
#       3 for i in range(1, 1000):
# ----> 4     j = j**i
#       5     print(j)
#
# OverflowError: (34, 'Numerical result out of range')

# %% [markdown]
# 10. KeyError: Ocurre cuando se intenta acceder a un diccionario con una clave que no existe.

# %%
ages = {'Jim': 30, 'Pamela': 28, 'Ana': 33}
ages['Rodrigo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-2075e65f78c4> in <module>
#       1 ages = {'Jim': 30, 'Pamela': 28, 'Ana': 33}
# ----> 2 ages['Rodrigo']
#
# KeyError: 'Rodrigo'

# %% [markdown]
# 11. FileNotFoundError: Ocurre cuando se intenta acceder a un fichero que no existe en la ruta indicada.

# %%
import os
import datetime

nombre_de_directorio = '/pruebas/'

for archivo in os.listdir(nombre_de_directorio):

    fecha_creacion = datetime.date.fromtimestamp(os.path.getmtime(archivo))
    print(str(archivo)+' '+str(fecha_creacion))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-4de28b1bb2a0> in <module>
#       4 nombre_de_directorio = '/pruebas/'
#       5
# ----> 6 for archivo in os.listdir(nombre_de_directorio):
#       7
#       8     fecha_creacion = datetime.date.fromtimestamp(os.path.getmtime(archivo))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/pruebas/'

# %% [markdown]
# 12. AttributeError: Ocurre ya que se hace una referencia de atributo de tipo  inválida, por lo que falla la asignación.

# %%
X = 10
X.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-8aa689ff3fa8> in <module>
#       1 X = 10
# ----> 2 X.append(6)
#
# AttributeError: 'int' object has no attribute 'append'

# %% [markdown]
# 13. IdentationError: Se presentan dos errores de identación en el código, uno de ellos en la definición de clases y otro
# dentro del if de la línea 9.

# %%
import random
lan='S'
class moneda:
counterS=0
    counterC=0
print("Ven a probar tu suerte con una ronda de lanzamientos de moneda")
while lan.upper()=='S':
    mon=random.choice(['Sello','Cara'])
    if mon=='Sello':
    print("Cayó Sello")
        moneda.counterS+=1
    elif mon=='Cara':
        print("Cayó Cara")
        moneda.counterC+=1
    lan=input('Desea realizar otro lanzamiento?: (S/N)')

print('Durante los lanzamientos salió Sello:',moneda.counterS,'veces')
print('Durante los lanzamientos salió Cara:',moneda.counterC,'veces')
# Out:
#   File "<ipython-input-14-75058de0366c>", line 4
#     counterS=0
#            ^
# IndentationError: expected an indented block

# %% [markdown]
# 14. ModuleNotFoundError: Al ejecutar el juego piedra, papel, tjieras desarrollado en Python usando la interfaz gráfica PyQt5 se presenta el siguiente error: No module named 'img'; esto se debe a que el archivo img que permite a la interfaz del programa cargar todas las imágenes se encuentra en formato . qrc el cual Python de forma nativa no puede ejecutar.

# %%
import sys
from img import *
from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtGui import *
from PyQt5.QtCore import *
from PyQt5.uic import loadUi
from PyQt5.QtWidgets import QWidget, QApplication, QMainWindow
import random


class WelcomeScreen(QMainWindow):
    def __init__(self):
        super(WelcomeScreen, self).__init__()
        loadUi("inicio.ui", self)
        self.frame.mouseMoveEvent = self.moveWindow
        self.salir.clicked.connect(self.exit)
        self.min.clicked.connect(self.minimizar)
        self.jugar.clicked.connect(self.window_access)

    def exit(self):
        app.exit()
        sys.exit()

    def moveWindow(self, e):
        if e.buttons() == Qt.LeftButton:
            self.move(self.pos() + e.globalPos() - self.clickPosition)
            self.clickPosition = e.globalPos()
            e.accept()

    def mousePressEvent(self, event):
        self.clickPosition = event.globalPos()

    def minimizar(self):
        widget.showMinimized()

    def window_access(self):
        ventana_2 = Gui_Juego()
        widget.addWidget(ventana_2)
        widget.setCurrentIndex(widget.currentIndex()+1)
        widget.setFixedHeight(768)
        widget.setFixedWidth(1366)


class Gui_Juego(QMainWindow):
    def __init__(self):
        super(Gui_Juego, self).__init__()
        loadUi("juego.ui", self)
        self.frame.mouseMoveEvent = self.moveWindow
        self.salir.clicked.connect(self.exit)
        self.min.clicked.connect(self.minimizar)
        self.piedra.clicked.connect(self.img_piedra)
        self.papel.clicked.connect(self.img_papel)
        self.tijera.clicked.connect(self.img_tijera)
        self.lagarto.clicked.connect(self.img_lagarto)
        self.spock.clicked.connect(self.img_spock)

    def exit(self):
        app.exit()
        sys.exit()

    def moveWindow(self, e):
        if e.buttons() == Qt.LeftButton:
            self.move(self.pos() + e.globalPos() - self.clickPosition)
            self.clickPosition = e.globalPos()
            e.accept()

    def mousePressEvent(self, event):
        self.clickPosition = event.globalPos()

    def minimizar(self):
        widget.showMinimized()

    def img_piedra(self):
        self.label_yo.setStyleSheet("border-image: url(:/imagenes/piedra.png);")
        self.computadora()
        if self.decision_computadora == 0:
            self.label_msg.setStyleSheet('color: pink;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Empate!")
        elif self.decision_computadora == 1 or self.decision_computadora == 4:
            self.label_msg.setStyleSheet('color: red;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Pierdes...")
        elif self.decision_computadora == 2 or self.decision_computadora == 3:
            self.label_msg.setStyleSheet('color: rgb(85, 255, 0);'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Ganaste!")

    def img_papel(self):
        self.label_yo.setStyleSheet("border-image: url(:/imagenes/papel.png);")
        self.computadora()
        if self.decision_computadora == 0 or self.decision_computadora == 4:
            self.label_msg.setStyleSheet('color: rgb(85, 255, 0);'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Ganaste")
        elif self.decision_computadora == 1:
            self.label_msg.setStyleSheet('color: pink;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Empate!")
        elif self.decision_computadora == 2 or self.decision_computadora == 3:
            self.label_msg.setStyleSheet('color: red;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Perdiste...")

    def img_tijera(self):
        self.label_yo.setStyleSheet("border-image: url(:/imagenes/tijera.png);")
        self.computadora()
        if self.decision_computadora == 0 or self.decision_computadora == 4:
            self.label_msg.setStyleSheet('color: red;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Pierdes...")
        elif self.decision_computadora == 1 or self.decision_computadora == 3:
            self.label_msg.setStyleSheet('color: rgb(85, 255, 0);'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Ganaste!")
        elif self.decision_computadora == 2:
            self.label_msg.setStyleSheet('color: pink;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Empate!")

    def img_lagarto(self):
        self.label_yo.setStyleSheet("border-image: url(:/imagenes/lagarto.png);")
        self.computadora()
        if self.decision_computadora == 0 or self.decision_computadora == 2:
            self.label_msg.setStyleSheet('color: red;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Pierdes...")
        elif self.decision_computadora == 1 or self.decision_computadora == 4:
            self.label_msg.setStyleSheet('color: rgb(85, 255, 0);'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Ganaste!")
        elif self.decision_computadora == 3:
            self.label_msg.setStyleSheet('color: pink;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Empate!")

    def img_spock(self):
        self.label_yo.setStyleSheet("border-image: url(:/imagenes/spock.png);")
        self.computadora()
        if self.decision_computadora == 1 or self.decision_computadora == 3:
            self.label_msg.setStyleSheet('color: red;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Pierdes...")
        elif self.decision_computadora == 2 or self.decision_computadora == 0:
            self.label_msg.setStyleSheet('color: rgb(85, 255, 0);'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Ganaste!")
        elif self.decision_computadora == 4:
            self.label_msg.setStyleSheet('color: pink;'
                                         'background-color: rgba(120,120,120,100);'
                                         'font: 30pt "Britannic Bold";')
            self.label_msg.setText("Empate!")

    def computadora(self):
        self.decision_computadora = random.randint(0, 4)
        if self.decision_computadora == 0:
            self.label_computadora.setStyleSheet("border-image: url(:/imagenes/piedra.png);")
        elif self.decision_computadora == 1:
            self.label_computadora.setStyleSheet("border-image: url(:/imagenes/papel.png);")
        elif self.decision_computadora == 2:
            self.label_computadora.setStyleSheet("border-image: url(:/imagenes/tijera.png);")
        elif self.decision_computadora == 3:
            self.label_computadora.setStyleSheet("border-image: url(:/imagenes/lagarto.png);")
        else:
            self.label_computadora.setStyleSheet("border-image: url(:/imagenes/spock.png);")


# main
app = QApplication(sys.argv)
welcome = WelcomeScreen()
widget = QtWidgets.QStackedWidget()
widget.addWidget(welcome)
widget.setFixedHeight(768)
widget.setFixedWidth(1366)
widget.setWindowFlags(QtCore.Qt.FramelessWindowHint)
widget.setAttribute(QtCore.Qt.WA_TranslucentBackground)
widget.show()
try:
    sys.exit(app.exec_())
except:
    print("Saliendo")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-8080c3279b8f> in <module>
#       1 import sys
# ----> 2 from img import *
#       3 from PyQt5 import QtCore, QtGui, QtWidgets
#       4 from PyQt5.QtGui import *
#       5 from PyQt5.QtCore import *
#
# ModuleNotFoundError: No module named 'img'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# 15. SyntaxError: Error de sintaxis al declarar una lista. Es muy común olvidar agregar el operador igual ( = ) al declarar listas, esto significa que se
# presentará un error de sintaxis el cual se puede solucionar de forma simple agregando un signo
# igual ( = ) antes de los corchetes ( [ ] ) que inicializan la lista vacía.

# %%
productos={"Combo 1":20000,"Combo 2":25000,"Combo 3":18000,"Combo 4":24500,"Papas":3000,"Jugos Naturales":7000,"Cerveza":3500,"Agua":4000,"Gaseosas":2500}
class counter:
    lista1[]
    total=0
    precio=0
dec1='S'
while dec1.upper()!='N':
    print('Que desea ordenar?')
    for i in productos:
        print(repr(i),"$:",productos[i])
    pedido=input("Ingrese el producto que desea: ")
    counter.lista1.append(pedido)
    counter.lista1.append(productos[pedido])
    dec1=input("Desea añadir algo más?: (S/N)")
    counter.precio=counter.precio+productos[pedido]
    counter.total=+counter.precio
    if dec1.upper()=='N':
        print("Ha ordenado: ",counter.lista1,"Costo total:",counter.precio)
        counter.precio=0

print("En el día se han recaudado:$",counter.total)
# Out:
#   File "<ipython-input-16-f62129c266fa>", line 3
#     lista1[]
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 16. TypeError: Error al operar entre tipos diferentes de datos. Cuando se emplean variables de un tipo diferente a las cadenas de caracteres ( str ) se debe
# declarar que tipo de dato se usará debido a que no es posible por ejemplo operar enteros con
# caracteres a pesar de que estos sean números .

# %%
a=input("Ingrese un número: ")
b=int(input("Ingrese otro número: "))
if b==0:
  print("Error. No es posible dividir entre 0")
  print("Reemplace el valor del segundo número")

elif b!=0:
  Respuesta=float(a/b)
  Residuo=float(a%b)
  print("El resultado es: ",Respuesta)
  print("El residuo es: ",Residuo)
# Out:
# Ingrese un número: 5
# Ingrese otro número: 4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-91bd7555ecdc> in <module>
#       6
#       7 elif b!=0:
# ----> 8   Respuesta=float(a/b)
#       9   Residuo=float(a%b)
#      10   print("El resultado es: ",Respuesta)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# 17. IndexError: Emplear ciclos para iterar dentro de una lista y pedir valores fuera de rango. Una forma de evitar los errores causados por equivocarse en el rango de una lista es usar:
# for i in “nombre de la lista” → for i in lista
# De forma que Python iterará las instrucciones tantas veces como datos existan dentro de la lista, a
# su vez esto hace que se deba imprimir únicamente el valor de i, que dejará de ser un entero en
# cada iteración y se convertirá en una cadena de caracteres.

# %%
lista=["Platano","Cebola","Tomate","Garbanzos","Arroz"]
print("El rango de la lista es: ",len(lista))
for i in range(0,12):
    print(lista[i])
# Out:
# El rango de la lista es:  5
# Platano
# Cebola
# Tomate
# Garbanzos
# Arroz
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-892cdba1fe41> in <module>
#       2 print("El rango de la lista es: ",len(lista))
#       3 for i in range(0,12):
# ----> 4     print(lista[i])
#
# IndexError: list index out of range

# %% [markdown]
# 18. Generar un bucle infinito debido a la falta de un cambio en su condición de iteración
#
# Olvidarse de agregar la condición que causará la salida de un bucle ocasiona que este se ejecute
# sin parar, especialmente cuando se trata de datos que pueden seguir operándose de forma
# indefinida, esto se puede solucionar dando la condición de salida dentro del bucle cuando se
# llegue a un cierto valor, o en los argumentos del ciclo usando operadores como lo es el operador
# “menor que” ( < ).
#
# (NO PROBAR)

# %%
num1=1
num2=2
while True:
    print(f"El resultado de {num1}*{num2} es: {num1*num2}")
    num1+=1
    num2+=1
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# El resultado de 9849*9850 es: 97012650
# El resultado de 9850*9851 es: 97032350
# El resultado de 9851*9852 es: 97052052
# El resultado de 9852*9853 es: 97071756
# El resultado de 9853*9854 es: 97091462
# El resultado de 9854*9855 es: 97111170
# El resultado de 9855*9856 es: 97130880
# El resultado de 9856*9857 es: 97150592
# El resultado de 9857*9858 es: 97170306
# El resultado de 9858*9859 es: 97190022
# El resultado de 9859*9860 es: 97209740
# El resultado de 9860*9861 es: 97229460
# El resultado de 9861*9862 es: 97249182
# El resultado de 9862*9863 es: 97268906
# El resultado de 9863*9864 es: 97288632
# El resultado de 9864*9865 es: 97308360
# El resultado de 9865*9866 es: 97328090
# El resultado de 9866*9867 es: 97347822
# El resultado de 9867*9868 es: 97367556
# El resultado de 9868*9869 es: 97387292
# El resultado de 9869*9870 es: 97407030
# El resultado de 9870*9871 es: 97426770
# ...

# %% [markdown]
# 19. Generar una función y olvidarse de invocarla cuando se necesita
#
# Aunque en si mismo no genera un error que Python pueda detectar, al realizar un programa el
# hecho de olvidarse de i invocar las funciones que has creado puede ocasionar fallos futuros al
# desarrollar programas de cada vez mayor tamaño
#
# A su vez otro error dentro del uso de funciones es no darle los argumentos que requiere para su
# funcionamiento

# %%
def address(street,city,postal_code):
    print("Tu dirección es:",street,city,postal_code)

s=input("Calle: ")
p_c=input("Código postal: ")
c=input("Ciudad: ")
# Out:
# Calle: Jardin
# Código postal: 680002
# Ciudad: BGA

# %% [markdown]
# 20. TypeError: Olvidar introducir argumentos a la función una vez han sido declarados en su definición. Esto se soluciona ingresando las variables que cumplen con la función de los argumentos de la
# función.

# %%
def address(street,city,postal_code):
    print("Tu dirección es:",street,city,postal_code)

s=input("Calle: ")
p_c=input("Código postal: ")
c=input("Ciudad: ")

address()
# Out:
# Calle: Jardin
# Código postal: 680002
# Ciudad: BGA
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c175fec3da19> in <module>
#       6 c=input("Ciudad: ")
#       7
# ----> 8 address()
#
# TypeError: address() missing 3 required positional arguments: 'street', 'city', and 'postal_code'
